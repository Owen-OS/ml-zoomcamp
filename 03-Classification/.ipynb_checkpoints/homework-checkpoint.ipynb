# %% [markdown]
# # Chapter 3. Homework

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv")
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %%
cat_cols = df.select_dtypes("object").columns
cat_cols
# Out:
# Index(['lead_source', 'industry', 'employment_status', 'location'], dtype='object')

# %%
num_cols = [col for col in df.columns if col not in cat_cols]
num_cols
# Out:
# ['number_of_courses_viewed',
#  'annual_income',
#  'interaction_count',
#  'lead_score',
#  'converted']

# %%
df[cat_cols] = df[cat_cols].fillna("NA")
df[num_cols] = df[num_cols].fillna(0.0)
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads          NA                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3                NA      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %% [markdown]
# ## Question 1.
# **Retail** is the most frequent industry

# %%
df.industry.value_counts().sort_values()
# Out:
# industry
# NA               134
# manufacturing    174
# technology       179
# healthcare       187
# education        187
# other            198
# finance          200
# retail           203
# Name: count, dtype: int64

# %% [markdown]
# ## Question 2.

# %%
df[num_cols].head()
# Out:
#    number_of_courses_viewed  annual_income  interaction_count  lead_score  \
# 0                         1        79450.0                  4        0.94
# 1                         1        46992.0                  1        0.80
# 2                         5        78796.0                  3        0.69
# 3                         2        83843.0                  1        0.87
# 4                         3        85012.0                  3        0.62
#
#    converted
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1

# %%
correlations = []
corr_dict = {}
for col1 in num_cols:
    corrs = list(df[num_cols].corrwith(df[col1]))
    correlations.append(corrs)

    temp = {}
    max_corr = 0
    pair = []
    for i, c in enumerate(corrs):
        temp[num_cols[i]] = abs(c)

        if c > max_corr and col1 != num_cols[i]:
            max_corr = c
            pair = [col1, num_cols[i]]

    corr_dict[col1] = temp
    
pair, max_corr
corr_dict
# Out:
# {'number_of_courses_viewed': {'number_of_courses_viewed': 1.0,
#   'annual_income': 0.009770285756444643,
#   'interaction_count': 0.023565222882888117,
#   'lead_score': 0.004878998354681257,
#   'converted': 0.435913658021179},
#  'annual_income': {'number_of_courses_viewed': 0.009770285756444643,
#   'annual_income': 1.0,
#   'interaction_count': 0.02703647240481436,
#   'lead_score': 0.015609546050138909,
#   'converted': 0.05313144169625193},
#  'interaction_count': {'number_of_courses_viewed': 0.023565222882888117,
#   'annual_income': 0.02703647240481436,
#   'interaction_count': 1.0,
#   'lead_score': 0.009888182496913084,
#   'converted': 0.3745725177994038},
#  'lead_score': {'number_of_courses_viewed': 0.004878998354681257,
#   'annual_income': 0.015609546050138907,
#   'interaction_count': 0.009888182496913084,
#   'lead_score': 1.0,
#   'converted': 0.1936734975869028},
#  'converted': {'number_of_courses_viewed': 0.435913658021179,
#   'annual_income': 0.05313144169625193,
#   'interaction_count': 0.3745725177994038,
#   'lead_score': 0.1936734975869028,
#   'converted': 1.0}}

# %%
#plt.matshow(correlations)
alpha = list(num_cols)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, interpolation='nearest')

fig.colorbar(cax)

plt.show()
