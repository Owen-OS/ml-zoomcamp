# %%
# !python3 -V
# Out:
# Python 3.12.12

# %%
# !wget https://www.github.com/alexeygrigorev/mlbookcamp-code/releases/download/chapter7-model/xception_v4_large_08_0.894.h5 -O clothing-model.h5
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]87[https://www.github.com/alexeyg]87clothing-model.h5      0% [<=>                           ]       0          B/s87HTTP response 301  [https://www.github.com/alexeygrigorev/mlbookcamp-code/releases/download/chapter7-model/xception_v4_large_08_0.894.h5]
# 87clothing-model.h5      0% [ <=>                          ]       0          B/s87Adding URL: https://github.com/alexeygrigorev/mlbookcamp-code/releases/download/chapter7-model/xception_v4_large_08_0.894.h5
# 87Adding URL: https://github.com/alexeygrigorev/mlbookcamp-code/releases/download/chapter7-model/xception_v4_large_08_0.894.h5
# 87[Files: 0  Bytes: 0  [0 B/s] Re]87[https://github.com/alexeygrigo]87clothing-model.h5      0% [<=>                           ]       0          B/s87HTTP response 302  [https://github.com/alexeygrigorev/mlbookcamp-code/releases/download/chapter7-model/xception_v4_large_08_0.894.h5]
# ...

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2025-12-16 09:14:10.284426: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
keras.models.load_model('clothing-model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /root/anaconda3/lib/python3.13/site-packages/keras/src/ops/operation.py:317, in Operation.from_config(cls, config)
#     316 try:
# --> 317     return cls(**config)
#     318 except Exception as e:
#
# File /root/anaconda3/lib/python3.13/site-packages/keras/src/layers/convolutional/separable_conv2d.py:122, in SeparableConv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, depth_multiplier, activation, use_bias, depthwise_initializer, pointwise_initializer, bias_initializer, depthwise_regularizer, pointwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, pointwise_constraint, bias_constraint, **kwargs)
#      99 def __init__(
#     100     self,
#     101     filters,
#    (...)
#     120     **kwargs,
#     121 ):
# --> 122     super().__init__(
# ...

# %%
# Out:
# /home/owen/Documents/ml-zoomcamp/ml-zoomcamp/09-Serverless
